# %% [markdown]
# 1.
#
# a) Given the string 'People Programming Python',  write three ways to get the letter 'P' using indexes
#
# b) Using the same string as above, write three ways using functions/methods to check if 'P' exists in the string.

# %%
s = 'People Programming Python'
# a)
print(s[0])
print(s[-len(s)])
print(s[-6])

# b)
print(s.find('P') >= 0)
print(s.count('P') > 0)
print(str.startswith(s, 'P'))
print('P' in s)
# Out:
# P
# P
# P
# True
# True
# True
# True

# %% [markdown]
# 2. Evaluate and explain each of the following expressions:
#
# - 5 + 5
#   - Returns 10. Just adds the two 5 literals.
#
# - 5 + '5'
#   - Unsupported operation. We cannot add an int to a string type.
#
# - '5' + '5'
#   - Concatenates the 2 '5' strings and returns '55'
#
# - 5 * 5
#   - Multiplies the 2 literal integers to give 25
#
# - 5 ** 5
#   - Takes the power of 5 raised to 5, returns 3125.
#
# - 5 * '5'
#   - Concatenates the string '5' 5 times, returns '55555'
#
# - 7 / 5
#   - Returns the quotient from dividing 7 with 5, returns 1.4
#
# - 7 // 5
#   - Rounds the quotient to an integer, returns 1

# %%
# 3. Using string slices and string methods, write five different ways to look 
# for or verify the existence of the substring 'Python' in the string 
# 'People Programming Python'. 

s = 'People Programming Python'
print('Python' in s)
print(s.endswith('Python'))
print(s[19:] == 'Python')
print(s[19::1] == 'Python')
# Out:
# True
# True
# True
# True

# %%
# 4. What is the result of the following?


s = 'This is a "simple" sentence.\n'

len(s) # 29
s.count('i') # 3
s.index('simple') # 11
s.find('simple', 12) # -1
s.title() # 'This Is A "Simple" Sentence.\n'
s.strip() # 'This is a "simple" sentence.'
s.replace('simple', 'short') # 'This is a "short" sentence.\n'
s[4].isspace() # True
s[5:7].upper() # 'IS'
s[s.index('sentence'):-2].capitalize() # 'Sentence'
# Out:
# 'Sentence'

# %%
# 5. A. Modify our high-low game so that it will keep track of the number of guesses.
#  If the player guesses more than 10 times, it should print a message "Too many guesses." and exit the program.

# Add another modification so that if the player’s guess is within 10, print a message "You are getting close." 

# a simple guess the number game
import random

# get a random number from 1 to max_number
max_number = 100
secret_number = random.randint(1, max_number)
print(f"I'm thinking of a number from 1 to {max_number}")
ctr = 0
# infinite loop
while True:
    if ctr > 10:
      print("Too many guesses.")
      break
    guess = input("Guess the number (type 'q' to quit):\n")
    ctr += 1
    if guess == 'q':
        break
    guess_number = int(guess)
    if guess_number == secret_number:
        print("Correct! That's the right number.")
        break
    elif guess_number < secret_number:
        print("Your guess is too low")
    elif guess_number > secret_number:
        print("Your guess is too high")
    if abs(guess_number - secret_number) <= 10:
      print("You are getting close.")

# end of loop
print("game over")
# Out:
# I'm thinking of a number from 1 to 100
# Guess the number (type 'q' to quit):
# 34
# Your guess is too low
# Guess the number (type 'q' to quit):
# 35
# Your guess is too low
# You are getting close.
# Guess the number (type 'q' to quit):
# 56
# Your guess is too high
# Guess the number (type 'q' to quit):
# 55
# Your guess is too high
# You are getting close.
# Guess the number (type 'q' to quit):
# 45
# Correct! That's the right number.
# game over

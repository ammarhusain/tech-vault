# %%
# NameError
n
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-de621a3ea95a> in <module>
#       1 # NameError
# ----> 2 n
#
# NameError: name 'n' is not defined

# %%
# ValueError
int('abc')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-683b8e6a8acd> in <module>
#       1 # ValueError
# ----> 2 int('abc')
#
# ValueError: invalid literal for int() with base 10: 'abc'

# %%
int('123')
# Out:
# 123

# %%
int('123.4')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-581646fd3721> in <module>
# ----> 1 int('123.4')
#
# ValueError: invalid literal for int() with base 10: '123.4'

# %%
# KeyError
d = { 'a':1 }
try:
    print(d['x'])
except KeyError:
    print('key does not exist')
# Out:
# key does not exist

# %%
# IndexError
mylist = [1, 2, 3, 4]
mylist[10]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-7-f6f65c415366> in <module>
#       1 # IndexError
#       2 mylist = [1, 2, 3, 4]
# ----> 3 mylist[10]
#
# IndexError: list index out of range

# %%
10/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-8-e574edb36883> in <module>
# ----> 1 10/0
#
# ZeroDivisionError: division by zero

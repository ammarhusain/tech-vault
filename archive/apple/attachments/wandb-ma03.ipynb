# %%
import wandb
import os

# !export WANDB_BASE_URL="https://mlrwandb-dev-05.spg.g.apple.com"

# db_user = os.environ.get('WANDB_BASE_URL')

# print(db_user)

# # Let wandb know we want to connect to our own internal W&B instance.
os.environ["WANDB_BASE_URL"] = "https://mlrwandb-dev-05.spg.g.apple.com"

# # Provide your personal API key.
os.environ["WANDB_API_KEY"] = "local-f92f2077a71582772ae4feee107979b308081d39"

wandb.init(project="my-first-project")
wandb.log({"metric": 1})
wandb.finish()
# Out:
# Changes to your `wandb` environment variables will be ignored because your `wandb` session has already started. For more information on how to modify your settings with `wandb.init()` arguments, please refer to <a href='https://wandb.me/wandb-init' target="_blank">the W&B docs</a>.
# Tracking run with wandb version 0.15.8
# Run data is saved locally in <code>/Users/ammarh/Desktop/wandb/run-20230815_191326-hyja4odn</code>
# Syncing run <strong><a href='https://wandb.ai/ammarh/my-first-project/runs/hyja4odn' target="_blank">dazzling-resonance-4</a></strong> to <a href='https://wandb.ai/ammarh/my-first-project' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/ammarh/my-first-project' target="_blank">https://wandb.ai/ammarh/my-first-project</a>
# ...

# %%
## WANDB Trial with OpenAI API
import openai
import datetime
import wandb, os
from wandb.sdk.data_types.trace_tree import Trace

os.environ["WANDB_API_KEY"] = "local-f92f2077a71582772ae4feee107979b308081d39"

openai.api_key = "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"

wandb.init(project="openai-trace-example")


# define your conifg
model_name = "gpt-3.5-turbo"
temperature = 0.7
system_message = "You are a helpful assistant that always replies in 3 concise bullet points using markdown."

queries_ls = [
  "What is the capital of France?",
  "How do I boil an egg?" * 10000,  # deliberately trigger an openai error
  "What to do if the aliens arrive?" 
]

for query in queries_ls:
    messages=[
      {"role": "system", "content": system_message},
      {"role": "user", "content": query}
    ]

    start_time_ms = datetime.datetime.now().timestamp() * 1000
    try:
      print(f"Calling openai {messages}")
      response = openai.ChatCompletion.create(model=model_name,
                                              messages=messages,
                                              temperature=temperature
                                              )   

      end_time_ms = round(datetime.datetime.now().timestamp() * 1000)  # logged in milliseconds
      status="success"
      status_message=None,
      response_text = response["choices"][0]["message"]["content"]
      token_usage = response["usage"].to_dict()
      
    
    except Exception as e:
      end_time_ms = round(datetime.datetime.now().timestamp() * 1000)  # logged in milliseconds
      status="error"
      status_message=str(e)
      response_text = ""
      token_usage = {}

    # create a span in wandb
    root_span = Trace(
          name="root_span",
          kind="llm",  # kind can be "llm", "chain", "agent" or "tool"
          status_code=status,
          status_message=status_message,
          metadata={"temperature": temperature,
                    "token_usage": token_usage, 
                    "model_name": model_name},
          start_time_ms=start_time_ms,
          end_time_ms=end_time_ms,
          inputs={"system_prompt": system_message, "query": query},
          outputs={"response": response_text},
          )
    
    # log the span to wandb
    root_span.log(name="openai_trace")
# Out:
# Finishing last run (ID:c65pcqaw) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
#  View run <strong style="color:#cdcd00">neat-spaceship-1</strong> at: <a href='https://wandb.ai/ammarh/openai-trace-example/runs/c65pcqaw' target="_blank">https://wandb.ai/ammarh/openai-trace-example/runs/c65pcqaw</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230817_102229-c65pcqaw/logs</code>
# Successfully finished last run (ID:c65pcqaw). Initializing new run:<br/>
# Tracking run with wandb version 0.15.8
# Run data is saved locally in <code>/Users/ammarh/Desktop/wandb/run-20230817_102600-0ldeufp1</code>
# ...

# %%
queries_ls = [
  "What is the capital of France?",
  "How do I boil an egg?",
  "What to do if the aliens arrive?" 
]

# %%
queries_ls = [
  "What is the capital of France?",
  "How do I boil an egg?",
  "What to do if the aliens arrive?" 
]

# %%
queries_ls = [
  "What is the capital of France?",
  "How do I boil an egg?",
  "What to do if the aliens arrive?" 
]

# %%
## WANDB Trial with LlamaCpp
from llama_cpp import Llama

llm = Llama(model_path='/Users/ammarh/j595/llama.cpp/models/llama-2/llama-2-13b-chat.ggmlv3.q8_0.bin')

os.environ["WANDB_API_KEY"] = "local-f92f2077a71582772ae4feee107979b308081d39"

openai.api_key = "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"

wandb.init(project="llama-trace-example")


# define your conifg
model_name = "llama-2-13b-chat.ggmlv3.q8_0.bin"
temperature = 0.7
max_tokens = -1
system_message = "You are a helpful assistant that always replies in 3 concise bullet points using markdown."

queries_ls = [
  "What is the capital of France?",
  "How do I boil an egg?",
  "What to do if the aliens arrive?" 
]

for query in queries_ls:
    messages=[
      {"role": "system", "content": system_message},
      {"role": "user", "content": query}
    ]

    start_time_ms = datetime.datetime.now().timestamp() * 1000
    try:
      prompt = messages[0]["content"] + "\n" +  messages[1]["content"]
      print(f"Calling llama {prompt}")
      out = llm.create_completion(prompt=prompt, max_tokens=-1, temperature=temperature)   

      end_time_ms = round(datetime.datetime.now().timestamp() * 1000)  # logged in milliseconds
      status="success"
      status_message=None,
      response_text = out['choices'][0]['text']
      token_usage = "not set"
      
    
    except Exception as e:
      end_time_ms = round(datetime.datetime.now().timestamp() * 1000)  # logged in milliseconds
      status="error"
      status_message=str(e)
      response_text = ""
      token_usage = {}

    # create a span in wandb
    root_span = Trace(
          name="root_span",
          kind="llm",  # kind can be "llm", "chain", "agent" or "tool"
          status_code=status,
          status_message=status_message,
          metadata={"temperature": temperature,
                    "token_usage": token_usage, 
                    "model_name": model_name},
          start_time_ms=start_time_ms,
          end_time_ms=end_time_ms,
          inputs={"prompt": prompt},
          outputs={"response": response_text},
          )
    
    # log the span to wandb
    root_span.log(name="llama_trace")
# Out:
# llama.cpp: loading model from /Users/ammarh/j595/llama.cpp/models/llama-2/llama-2-13b-chat.ggmlv3.q8_0.bin
# llama_model_load_internal: format     = ggjt v3 (latest)
# llama_model_load_internal: n_vocab    = 32000
# llama_model_load_internal: n_ctx      = 512
# llama_model_load_internal: n_embd     = 5120
# llama_model_load_internal: n_mult     = 256
# llama_model_load_internal: n_head     = 40
# llama_model_load_internal: n_layer    = 40
# llama_model_load_internal: n_rot      = 128
# llama_model_load_internal: ftype      = 7 (mostly Q8_0)
# llama_model_load_internal: n_ff       = 13824
# llama_model_load_internal: model size = 13B
# llama_model_load_internal: ggml ctx size =    0.09 MB
# llama_model_load_internal: mem required  = 15237.96 MB (+ 1608.00 MB per state)
# llama_new_context_with_model: kv self size  =  400.00 MB
# ...
